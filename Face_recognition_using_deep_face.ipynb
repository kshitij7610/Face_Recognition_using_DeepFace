# %%
import cv2
from deepface import DeepFace
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

cap = cv2.VideoCapture(0)

if not cap.isOpened():
  cap = cv2.VideoCapture(1)

if not cap.isOpened():
  raise IOError("Cannot open Webcam")

while True:
  ret,frame = cap.read()
  result = DeepFace.analyze(frame,actions = ['emotion'])

  gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)

  faces = faceCascade.detectMultiScale(gray,1.1,4)

  #Drawing rectangles
  for (x,y,w,h) in faces:
    cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),2)

  font = cv2.FONT_HERSHEY_SIMPLEX

  #Using putText() method for inserting text on video

  cv2.putText(frame,result['dominant_emotion'],(50,50),font,3,(0,0,255),2,cv2.LINE_4)
  cv2.imshow('Original video',frame)

  if cv2.waitKey(2) & 0xFF == ord('q'):
    break

cap.release()
cv2.destroyAllWindows()
# Out:
# Directory  C:\Users\kshit /.deepface created
# Directory  C:\Users\kshit /.deepface/weights created
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://drive.google.com/uc?id=13iUHHP3SlNg53qSuQZDdHDSDNdBP9nwy
# To: C:\Users\kshit\.deepface\weights\facial_expression_model_weights.zip
# 5.54MB [00:15, 364kB/s]

# %%
pip install deepface
# Out:
# Collecting deepface
#   Using cached deepface-0.0.51-py3-none-any.whl (57 kB)
# Requirement already satisfied: keras>=2.2.0 in c:\users\kshit\anaconda3\lib\site-packages (from deepface) (2.4.3)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\kshit\anaconda3\lib\site-packages (from deepface) (2.4.1)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\kshit\anaconda3\lib\site-packages (from deepface) (4.42.1)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\kshit\anaconda3\lib\site-packages (from deepface) (0.1.0)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\kshit\anaconda3\lib\site-packages (from deepface) (3.12.2)
# Requirement already satisfied: opencv-python>=3.4.4 in c:\users\kshit\anaconda3\lib\site-packages (from deepface) (4.5.1.48)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\kshit\appdata\roaming\python\python37\site-packages (from deepface) (1.1.4)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\kshit\appdata\roaming\python\python37\site-packages (from deepface) (8.0.1)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\kshit\anaconda3\lib\site-packages (from deepface) (1.19.5)
# Requirement already satisfied: retina-face>=0.0.1 in c:\users\kshit\anaconda3\lib\site-packages (from deepface) (0.0.3)
# Collecting Flask>=1.1.2
#   Using cached Flask-1.1.2-py2.py3-none-any.whl (94 kB)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\kshit\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\kshit\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (2.11.1)
# Requirement already satisfied: click>=5.1 in c:\users\kshit\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (7.0)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\kshit\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (1.0.0)
# Requirement already satisfied: requests[socks] in c:\users\kshit\appdata\roaming\python\python37\site-packages (from gdown>=3.10.1->deepface) (2.25.0)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\kshit\anaconda3\lib\site-packages (from deepface) (4.42.1)
# Requirement already satisfied: filelock in c:\users\kshit\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (3.0.12)
# Requirement already satisfied: six in c:\users\kshit\appdata\roaming\python\python37\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\kshit\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.1.2->deepface) (1.1.1)
# Requirement already satisfied: scipy>=0.14 in c:\users\kshit\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (1.4.1)
# Requirement already satisfied: pyyaml in c:\users\kshit\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (5.3)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\kshit\anaconda3\lib\site-packages (from deepface) (1.19.5)
# Requirement already satisfied: h5py in c:\users\kshit\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (2.10.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\kshit\anaconda3\lib\site-packages (from deepface) (1.19.5)
# Requirement already satisfied: six in c:\users\kshit\appdata\roaming\python\python37\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: opencv-python>=3.4.4 in c:\users\kshit\anaconda3\lib\site-packages (from deepface) (4.5.1.48)
# Requirement already satisfied: keras>=2.2.0 in c:\users\kshit\anaconda3\lib\site-packages (from deepface) (2.4.3)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\kshit\anaconda3\lib\site-packages (from deepface) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in c:\users\kshit\appdata\roaming\python\python37\site-packages (from pandas>=0.23.4->deepface) (2020.4)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\kshit\anaconda3\lib\site-packages (from deepface) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\kshit\appdata\roaming\python\python37\site-packages (from pandas>=0.23.4->deepface) (2.8.1)
# Requirement already satisfied: six in c:\users\kshit\appdata\roaming\python\python37\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kshit\appdata\roaming\python\python37\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.26.2)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\kshit\appdata\roaming\python\python37\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kshit\appdata\roaming\python\python37\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2020.11.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\kshit\appdata\roaming\python\python37\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\kshit\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kshit\appdata\roaming\python\python37\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.26.2)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\kshit\appdata\roaming\python\python37\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kshit\appdata\roaming\python\python37\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2020.11.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\kshit\appdata\roaming\python\python37\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.0.4)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\kshit\anaconda3\lib\site-packages (from deepface) (2.4.1)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\kshit\anaconda3\lib\site-packages (from deepface) (3.12.2)
# Requirement already satisfied: opencv-python>=3.4.4 in c:\users\kshit\anaconda3\lib\site-packages (from deepface) (4.5.1.48)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\kshit\appdata\roaming\python\python37\site-packages (from deepface) (8.0.1)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\kshit\anaconda3\lib\site-packages (from deepface) (1.19.5)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\kshit\anaconda3\lib\site-packages (from deepface) (1.19.5)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\kshit\anaconda3\lib\site-packages (from deepface) (1.19.5)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\kshit\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: absl-py~=0.10 in c:\users\kshit\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.12.0)
# Requirement already satisfied: gast==0.3.3 in c:\users\kshit\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.3.3)
# Requirement already satisfied: tensorboard~=2.4 in c:\users\kshit\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.5.0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\kshit\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.1.0)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in c:\users\kshit\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.4.0)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\kshit\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\kshit\appdata\roaming\python\python37\site-packages (from tensorflow>=1.9.0->deepface) (3.14.0)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\kshit\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.12.1)
# Requirement already satisfied: wheel~=0.35 in c:\users\kshit\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.36.2)
# Requirement already satisfied: six in c:\users\kshit\appdata\roaming\python\python37\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\kshit\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.12)
# Requirement already satisfied: h5py in c:\users\kshit\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (2.10.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\kshit\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.1.2)
# Requirement already satisfied: grpcio~=1.32.0 in c:\users\kshit\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.32.0)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\kshit\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\kshit\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.7.4.3)
# Requirement already satisfied: six in c:\users\kshit\appdata\roaming\python\python37\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: six in c:\users\kshit\appdata\roaming\python\python37\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: wheel~=0.35 in c:\users\kshit\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.36.2)
# Requirement already satisfied: six in c:\users\kshit\appdata\roaming\python\python37\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: six in c:\users\kshit\appdata\roaming\python\python37\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: six in c:\users\kshit\appdata\roaming\python\python37\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\kshit\anaconda3\lib\site-packages (from deepface) (1.19.5)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\kshit\anaconda3\lib\site-packages (from deepface) (1.19.5)
# Requirement already satisfied: six in c:\users\kshit\appdata\roaming\python\python37\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\kshit\appdata\roaming\python\python37\site-packages (from tensorflow>=1.9.0->deepface) (3.14.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\kshit\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (0.4.4)
# Requirement already satisfied: wheel~=0.35 in c:\users\kshit\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.36.2)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\kshit\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (1.0.0)
# Requirement already satisfied: absl-py~=0.10 in c:\users\kshit\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.12.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\kshit\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (3.3.4)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\kshit\anaconda3\lib\site-packages (from deepface) (1.19.5)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\kshit\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (1.8.0)
# Requirement already satisfied: grpcio~=1.32.0 in c:\users\kshit\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.32.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\kshit\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (0.6.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\kshit\appdata\roaming\python\python37\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (1.23.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\kshit\appdata\roaming\python\python37\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (50.3.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\kshit\appdata\roaming\python\python37\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (4.1.1)
# Requirement already satisfied: six in c:\users\kshit\appdata\roaming\python\python37\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\kshit\appdata\roaming\python\python37\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (50.3.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\kshit\appdata\roaming\python\python37\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\kshit\appdata\roaming\python\python37\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (0.2.8)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\kshit\appdata\roaming\python\python37\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (1.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\kshit\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (1.3.0)
# Requirement already satisfied: importlib-metadata in c:\users\kshit\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (1.5.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\kshit\anaconda3\lib\site-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (2.2.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\kshit\appdata\roaming\python\python37\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\kshit\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\kshit\appdata\roaming\python\python37\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (0.4.8)
# Installing collected packages: Flask, deepface
#   Attempting uninstall: Flask
#     Found existing installation: Flask 1.1.1
#     Uninstalling Flask-1.1.1:
#       Successfully uninstalled Flask-1.1.1
# Successfully installed Flask-1.1.2 deepface-0.0.51
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.3; however, version 21.1 is available.
# You should consider upgrading via the 'C:\Users\kshit\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\kshit\appdata\roaming\python\python37\site-packages (20.3)
# Collecting pip
#   Downloading pip-21.1-py3-none-any.whl (1.5 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 20.3
#     Uninstalling pip-20.3:
#       Successfully uninstalled pip-20.3
#   Rolling back uninstall of pip
#   Moving to c:\users\kshit\appdata\roaming\python\python37\scripts\pip.exe
#    from C:\Users\kshit\AppData\Local\Temp\pip-uninstall-5nyt1s0s\pip.exe
#   Moving to c:\users\kshit\appdata\roaming\python\python37\scripts\pip3.7.exe
#    from C:\Users\kshit\AppData\Local\Temp\pip-uninstall-5nyt1s0s\pip3.7.exe
#   Moving to c:\users\kshit\appdata\roaming\python\python37\scripts\pip3.exe
#    from C:\Users\kshit\AppData\Local\Temp\pip-uninstall-5nyt1s0s\pip3.exe
#   Moving to c:\users\kshit\appdata\roaming\python\python37\site-packages\pip-20.3.dist-info\
#    from c:\users\kshit\appdata\roaming\python\python37\site-packages\~ip-20.3.dist-info
#   Moving to c:\users\kshit\appdata\roaming\python\python37\site-packages\pip\
#    from c:\users\kshit\appdata\roaming\python\python37\site-packages\~ip
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\kshit\AppData\Roaming\Python\Python37\site-packages\pip\_internal\cli\base_command.py", line 210, in _main
#     status = self.run(options, args)
#   File "C:\Users\kshit\AppData\Roaming\Python\Python37\site-packages\pip\_internal\cli\req_command.py", line 180, in wrapper
#     return func(self, options, args)
#   File "C:\Users\kshit\AppData\Roaming\Python\Python37\site-packages\pip\_internal\commands\install.py", line 401, in run
#     pycompile=options.compile,
#   File "C:\Users\kshit\AppData\Roaming\Python\Python37\site-packages\pip\_internal\req\__init__.py", line 90, in install_given_reqs
#     pycompile=pycompile,
#   File "C:\Users\kshit\AppData\Roaming\Python\Python37\site-packages\pip\_internal\req\req_install.py", line 824, in install
#     requested=self.user_supplied,
#   File "C:\Users\kshit\AppData\Roaming\Python\Python37\site-packages\pip\_internal\operations\install\wheel.py", line 845, in install_wheel
#     requested=requested,
#   File "C:\Users\kshit\AppData\Roaming\Python\Python37\site-packages\pip\_internal\operations\install\wheel.py", line 747, in _install_wheel
#     generated_console_scripts = maker.make_multiple(scripts_to_generate)
#   File "C:\Users\kshit\AppData\Roaming\Python\Python37\site-packages\pip\_vendor\distlib\scripts.py", line 418, in make_multiple
#     filenames.extend(self.make(specification, options))
#   File "C:\Users\kshit\AppData\Roaming\Python\Python37\site-packages\pip\_internal\operations\install\wheel.py", line 483, in make
#     return super(PipScriptMaker, self).make(specification, options)
#   File "C:\Users\kshit\AppData\Roaming\Python\Python37\site-packages\pip\_vendor\distlib\scripts.py", line 407, in make
#     self._make_script(entry, filenames, options=options)
#   File "C:\Users\kshit\AppData\Roaming\Python\Python37\site-packages\pip\_vendor\distlib\scripts.py", line 307, in _make_script
#     self._write_script(scriptnames, shebang, script, filenames, ext)
#   File "C:\Users\kshit\AppData\Roaming\Python\Python37\site-packages\pip\_vendor\distlib\scripts.py", line 242, in _write_script
#     launcher = self._get_launcher('t')
#   File "C:\Users\kshit\AppData\Roaming\Python\Python37\site-packages\pip\_vendor\distlib\scripts.py", line 386, in _get_launcher
#     raise ValueError(msg)
# ValueError: Unable to find resource t64.exe in package pip._vendor.distlib
# WARNING: You are using pip version 20.3; however, version 21.1 is available.
# You should consider upgrading via the 'C:\Users\kshit\anaconda3\python.exe -m pip install --upgrade pip' command.
